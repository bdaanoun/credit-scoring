# %%
import pandas as pd

df = pd.read_csv("../data/bureau.csv")
df
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0            215354       5714462        Closed      currency 1         -497
# 1            215354       5714463        Active      currency 1         -208
# 2            215354       5714464        Active      currency 1         -203
# 3            215354       5714465        Active      currency 1         -203
# 4            215354       5714466        Active      currency 1         -629
# ...             ...           ...           ...             ...          ...
# 1716423      259355       5057750        Active      currency 1          -44
# 1716424      100044       5057754        Closed      currency 1        -2648
# 1716425      100044       5057762        Closed      currency 1        -1809
# 1716426      246829       5057770        Closed      currency 1        -1878
# 1716427      246829       5057778        Closed      currency 1         -463
#
# ...

# %%
print(df["AMT_CREDIT_SUM"].max())
# df["CREDIT_DAY_OVERDUE"].value_counts()
# Out:
# 585000000.0

# %%
df1 = pd.read_csv("../data/previous_application.csv")
df1
prev_app_count = df1.groupby("SK_ID_CURR")["SK_ID_PREV"].count()
# for col in df1.columns:
#     print(col)
df1["AMT_APPLICATION"].min()
# Out:
# np.float64(0.0)

# %%
df1["CREDIT_APPLICATION_RATIO"] = (
        df1["AMT_CREDIT"]
        / df1["AMT_APPLICATION"].replace(0, pd.NA)
    )

ratio_features = (
        df1.groupby("SK_ID_CURR")["CREDIT_APPLICATION_RATIO"]
        .agg(["mean", "max", "min"])
    )
ratio_features
# Out:
#                 mean       max       min
# SK_ID_CURR
# 100001      0.957782  0.957782  0.957782
# 100002           1.0       1.0       1.0
# 100003      1.057664   1.15098  0.989013
# 100004      0.828021  0.828021  0.828021
# 100005       0.89995   0.89995   0.89995
# ...              ...       ...       ...
# 456251           1.0       1.0       1.0
# 456252      0.986561  0.986561  0.986561
# 456253      0.831397  0.944436  0.718359
# 456254       1.12205  1.138491  1.105608
# 456255      1.115884     1.396       1.0
#
# [338857 rows x 3 columns]

# %%
status_counts = pd.crosstab(
        df1["SK_ID_CURR"],
        df1["NAME_CONTRACT_STATUS"]
    )
status_counts
# Out:
# NAME_CONTRACT_STATUS  Approved  Canceled  Refused  Unused offer
# SK_ID_CURR
# 100001                       1         0        0             0
# 100002                       1         0        0             0
# 100003                       3         0        0             0
# 100004                       1         0        0             0
# 100005                       1         1        0             0
# ...                        ...       ...      ...           ...
# 456251                       1         0        0             0
# 456252                       1         0        0             0
# 456253                       2         0        0             0
# 456254                       2         0        0             0
# 456255                       6         0        2             0
#
# [338857 rows x 4 columns]

# %%
df1["NFLAG_INSURED_ON_APPROVAL"]
# Out:
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          NaN
#           ...
# 1670209    0.0
# 1670210    0.0
# 1670211    0.0
# 1670212    1.0
# 1670213    0.0
# Name: NFLAG_INSURED_ON_APPROVAL, Length: 1670214, dtype: float64

# %%
df2 = pd.read_csv("../data/installments_payments.csv")
print(df2.shape)
df2.columns.tolist()
# Out:
# (13605401, 8)
# ['SK_ID_PREV',
#  'SK_ID_CURR',
#  'NUM_INSTALMENT_VERSION',
#  'NUM_INSTALMENT_NUMBER',
#  'DAYS_INSTALMENT',
#  'DAYS_ENTRY_PAYMENT',
#  'AMT_INSTALMENT',
#  'AMT_PAYMENT']

# %%
df2["NUM_INSTALMENT_VERSION"]
# Out:
# 0           1.0
# 1           0.0
# 2           2.0
# 3           1.0
# 4           1.0
#            ...
# 13605396    0.0
# 13605397    0.0
# 13605398    0.0
# 13605399    0.0
# 13605400    1.0
# Name: NUM_INSTALMENT_VERSION, Length: 13605401, dtype: float64
